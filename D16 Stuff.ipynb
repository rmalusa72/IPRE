# %%
.ORIG x3000
LD R0, START_ADDRESS
JMP R0

START_ADDRESS: .FILL START

;; Setup for the stack 
Top:    .FILL Stack
Stack:  .BLKW #100

PUSH:   LD R5, Top
        STR R0, R5, #0      ;; Save R0 to Stack
        ADD R5, R5, #1      ;; Increment Stack
        STR R1, R5, #0      ;; Save R1 to Stack
        ADD R5, R5, #1      ;; Increment Stack
        STR R2, R5, #0      ;; Save R2 to Stack
        ADD R5, R5, #1      ;; Increment Stack
        STR R3, R5, #0      ;; Save R3 to Stack
        ADD R5, R5, #1      ;; Increment Stack
        STR R4, R5, #0      ;; Save R4 to Stack
        ADD R5, R5, #1      ;; Increment Stack
        STR R6, R5, #0      ;; Save R6 to Stack
        ADD R5, R5, #1      ;; Increment Stack
        STR R7, R5, #0      ;; Save R7 to Stack
        ADD R5, R5, #1      ;; Increment Stack
        ST R5, Top
        JMP R6
        
POP:    LD R5, Top
        ADD R5, R5, #-1     ;; Decrement Stack
        LDR R7, R5, #0      ;; Load stack into R7
        ADD R5, R5, #-1     ;; Decrement Stack
        LDR R6, R5, #0      ;; Load Stack into R6
        ADD R5, R5, #-1     ;; Decrement Stack
        LDR R4, R5, #0      ;; Load Stack into R4
        ADD R5, R5, #-1     ;; Decrement Stack
        LDR R3, R5, #0      ;; Load Stack into R3
        ADD R5, R5, #-1     ;; Decrement Stack
        LDR R2, R5, #0      ;; Load Stack into R2
        ADD R5, R5, #-1     ;; Decrement Stack
        LDR R1, R5, #0      ;; Load Stack into R1
        ADD R5, R5, #-1     ;; Decrement Stack
        LDR R0, R5, #0      ;; Load Stack into R0
        ST R5, Top
        RET

;;;------------------------------------------------------
START: 

    LEA R6, D16
    JSR PUSH
    
    LD R0, D16_roll
    OUT
    HALT

;;; -----------------------------------------------------
;;; After this runs, result in D16_roll
D16: 
    ;; Call Random, loading a new random number into X
    LEA R6, Random
    JSR Push
    
    LD R0, X
    AND R0, R0, #15
    ADD R0, R0, #1
    ST R0, D16_roll
    
    LEA R0, POP
    JMP R0
D16_roll: .FILL #0


;;; -----------------------------------------------------
;;; Memory X has next random number
Random: 
    LD R0, M
    LD R1, A
    
    LEA R6, Divide
    JSR PUSH         ; R0 / R1
    
    ;; q = m / a
    LD R0, QUOTIENT     ; R0 / R1
    ST R0, Q 
    ;; r = m mod a
    LD R0, REMAINDER    ; R0 mod R1
    ST R0, R
        ;; x / q
    LD R0, X
    LD R1, Q
    
    LEA R6, Divide
    JSR PUSH        ; R0 / R1
    
    LD R1, QUOTIENT
    ST R1, TEMP2
    LD R1, REMAINDER    ; x mod q
    ST R1, TEMP1
    ;;      a * TEMP1 - r * TEMP2
    LD R0, A
    
    LEA R6, Multiply
    JSR PUSH        
    LD R2, MULT_PRODUCT  ; R2 <- R0 * R1
    
    ST R2, TEMP1
    ;;      a * TEMP1 - r * TEMP2
    LD R0, R
    LD R1, TEMP2
    
    LEA R6, Multiply
    JSR PUSH            
    LD R2, MULT_PRODUCT ; R2 <- r * TEMP2
    
    NOT R2,R2           ; -R2
    ADD R2,R2,#1
    ST R2, TEMP2 
    LD R1, TEMP1
    ADD R2, R2, R1      ; TEMP1 - TEMP2
    
TEST:  BRzp DONE        ; if x < 0 then
    LD R1, M
    ADD R2, R2, R1      ; 
DONE: ST R2, X
    LEA R0, POP         ;; Return
    JMP R0

A: .FILL #7             ;; a , the multiplicative constant is given
M: .FILL #32767         ;; m = 2 Ë† 15 âˆ’ 1, the modulus is given
X: .FILL #10            ;; x, the seed is given
R: .FILL #0
Q: .FILL #0
TEMP1: .FILL #0
TEMP2: .FILL #0
BACK: .FILL #0

;;; -----------------------------------------------------
;;; Mult_Product <- R0 * R1
;;; Also uses R3 to store SIGN
Multiply: AND R2,R2,#0
  AND R3,R3,#0
  ADD R0,R0,#0         ; compare R0
  BRn MultNEG1
  BR  MultCont
MultNEG1: NOT R3,R3         ; flip SIGN
  NOT R0,R0
  ADD R0,R0,#1
MultCONT: ADD R1,R1,#0         ; compare R1
  BRn MultNEG2
  BR MultInit
MultNEG2: NOT R3,R3         ; flip SIGN
  NOT R1,R1
  ADD R1,R1,#1
MultInit: ADD R0,R0,#0      ; have R0 set the condition codes
MultLoop: BRz MultDone
  ADD R2,R2,R1
  ADD R0,R0,#-1
  BR MultLoop
MultDone: ADD R0,R3,#0
  BRzp MultRet
  NOT R2,R2
  ADD R2,R2,#1
MultRet:
  ST R2, MULT_PRODUCT           ; Product has the product
  LEA R0, POP
  JMP R0
  
MULT_PRODUCT: .FILL #0

;;; -----------------------------------------------------
;;; R0 / R1
;;; Also uses R3 to store SIGN
;;;           R4 to store -R1
;;;           R5 is QUOTIENT
;;;           R6 is REMAINDER
;;;           R2 temp
Divide:   AND R3,R3,#0
  ST R3, QUOTIENT
  ST R3, REMAINDER
  ADD R0,R0,#0         ; compare R0
  BRn DivNEG1
  BR  DivCont
DivNEG1:  NOT R3,R3         ; flip SIGN
  NOT R0,R0
  ADD R0,R0,#1
DivCONT:  ADD R1,R1,#0         ; compare R1
  BRn DivNEG2
  BR DivInit
DivNEG2:  NOT R3,R3         ; flip SIGN
  NOT R1,R1
  ADD R1,R1,#1
DivInit:  ADD R4,R1,#0
  NOT R4,R4
  ADD R4,R4,#1
DivLoop:  ADD R2,R0,R4      ; have R2 set the condition codes
  BRn DivDone
  ADD R0,R0,R4
  LD R2,QUOTIENT
  ADD R2,R2,#1
  ST R2,QUOTIENT
  BR DivLoop
DivDone:  ADD R3,R3,#0         ; Negative?
  BRzp DivRet
  LD R2,QUOTIENT     ; Yes, then negate R2
  NOT R2,R2
  ADD R2,R2,#1
  ST R2,QUOTIENT
DivRet:      ST R0,REMAINDER
  LEA R0, POP
  JMP R0
QUOTIENT: .FILL #0
REMAINDER: .FILL #0
.END
# Out:
# Assembled! Use %dis or %dump to examine; use %exe to run.

# %%
%exe
# Out:
# ============================================================
# Computation completed
# ============================================================
# Instructions: 33137
# Cycles: 232128 (0.116064 milliseconds)
#
# ============================================================
# Registers:
# ============================================================
# PC: x048E
# N: 0 Z: 1 P: 0
# R0: x0004 R1: x0000 R2: x0000 R3: x0000
# R4: x0000 R5: x3004 R6: x308F R7: x308F

# %%
%dis 30A4
# Out:
# ============================================================
# Memory disassembled:
# ============================================================
#            x30A4: x225D  LD R1, QUOTIENT                           [line: 96]
#            x30A5: x321D  ST R1, TEMP2                              [line: 97]
#            x30A6: x225C  LD R1, REMAINDER                          [line: 98]
#            x30A7: x321A  ST R1, TEMP1                              [line: 99]
#            x30A8: x2014  LD R0, A                                  [line: 101]
#            x30A9: xE01B  LEA R0, MULTIPLY                          [line: 103]
#            x30AA: x4FBD  JSR PUSH                                  [line: 104]
#            x30AB: x2433  LD R2, MULT_PRODUCT                       [line: 105]
#            x30AC: x3415  ST R2, TEMP1                              [line: 107]
#            x30AD: x2012  LD R0, R                                  [line: 109]
#            x30AE: x2214  LD R1, TEMP2                              [line: 110]
#            x30AF: xE015  LEA R0, MULTIPLY                          [line: 112]
#            x30B0: x4FB7  JSR PUSH                                  [line: 113]
#            x30B1: x242D  LD R2, MULT_PRODUCT                       [line: 114]
#            x30B2: x94BF  NOT R2, R2                                [line: 116]
#            x30B3: x14A1  ADD R2, R2, #1                            [line: 117]
#            x30B4: x340E  ST R2, TEMP2                              [line: 118]
#            x30B5: x220C  LD R1, TEMP1                              [line: 119]
#            x30B6: x1481  ADD R2, R2, R1                            [line: 120]
# TEST:      x30B7: x0602  BRzp DONE (or 2)                          [line: 122]
#            x30B8: x2205  LD R1, M                                  [line: 123]
#            x30B9: x1481  ADD R2, R2, R1                            [line: 124]
# DONE:      x30BA: x3404  ST R2, X                                  [line: 125]
#            x30BB: xE1BD  LEA R0, POP                               [line: 126]
#            x30BC: xC000  JMP R0                                    [line: 127]
# A:         x30BD: x0007  NOOP - (no BR to MULTIPLY) (or 7)         [line: 129]
# M:         x30BE: x7FFF  STR R7, R7, 63                            [line: 130]
# X:         x30BF: x000A  NOOP - (no BR to MULTNEG1) (or 10)        [line: 131]
# R:         x30C0: x0000  NOOP - (no BR to Q) (or 0)                [line: 132]
# Q:         x30C1: x1249  ADD R1, R1, R1                            [line: 133]
# TEMP1:     x30C2: x0000  NOOP - (no BR to TEMP2) (or 0)            [line: 134]
# TEMP2:     x30C3: x0000  NOOP - (no BR to BACK) (or 0)             [line: 135]
# BACK:      x30C4: x0000  NOOP - (no BR to MULTIPLY) (or 0)         [line: 136]
# MULTIPLY:  x30C5: x54A0  AND R2, R2, #0                            [line: 141]
#            x30C6: x56E0  AND R3, R3, #0                            [line: 142]
#            x30C7: x1020  ADD R0, R0, #0                            [line: 143]
#            x30C8: x0801  BRn MULTNEG1 (or 1)                       [line: 144]
#            x30C9: x0E03  BRnzp MULTCONT (or 3)                     [line: 145]
# MULTNEG1:  x30CA: x96FF  NOT R3, R3                                [line: 146]
#            x30CB: x903F  NOT R0, R0                                [line: 147]
#            x30CC: x1021  ADD R0, R0, #1                            [line: 148]
# MULTCONT:  x30CD: x1260  ADD R1, R1, #0                            [line: 149]
#            x30CE: x0801  BRn MULTNEG2 (or 1)                       [line: 150]
#            x30CF: x0E03  BRnzp MULTINIT (or 3)                     [line: 151]
# MULTNEG2:  x30D0: x96FF  NOT R3, R3                                [line: 152]
#            x30D1: x927F  NOT R1, R1                                [line: 153]
#            x30D2: x1261  ADD R1, R1, #1                            [line: 154]
# MULTINIT:  x30D3: x1020  ADD R0, R0, #0                            [line: 155]
# MULTLOOP:  x30D4: x0403  BRz MULTDONE (or 3)                       [line: 156]
#            x30D5: x1481  ADD R2, R2, R1                            [line: 157]
#            x30D6: x103F  ADD R0, R0, #-1                           [line: 158]
#            x30D7: x0FFC  BRnzp MULTLOOP                            [line: 159]
# MULTDONE:  x30D8: x10E0  ADD R0, R3, #0                            [line: 160]
#            x30D9: x0602  BRzp MULTRET (or 2)                       [line: 161]
#            x30DA: x94BF  NOT R2, R2                                [line: 162]
#            x30DB: x14A1  ADD R2, R2, #1                            [line: 163]
# MULTRET:   x30DC: x3402  ST R2, MULT_PRODUCT                       [line: 165]
#            x30DD: xE19B  LEA R0, POP                               [line: 166]
#            x30DE: xC000  JMP R0                                    [line: 167]
# MULT_PRODUCT: x30DF: x0000  NOOP - (no BR to DIVIDE) (or 0)           [line: 169]
# DIVIDE:    x30E0: x56E0  AND R3, R3, #0                            [line: 178]
#            x30E1: x3620  ST R3, QUOTIENT                           [line: 179]
#            x30E2: x3620  ST R3, REMAINDER                          [line: 180]
#            x30E3: x1020  ADD R0, R0, #0                            [line: 181]
#            x30E4: x0801  BRn DIVNEG1 (or 1)                        [line: 182]
#            x30E5: x0E03  BRnzp DIVCONT (or 3)                      [line: 183]
# DIVNEG1:   x30E6: x96FF  NOT R3, R3                                [line: 184]
#            x30E7: x903F  NOT R0, R0                                [line: 185]
#            x30E8: x1021  ADD R0, R0, #1                            [line: 186]
# DIVCONT:   x30E9: x1260  ADD R1, R1, #0                            [line: 187]
#            x30EA: x0801  BRn DIVNEG2 (or 1)                        [line: 188]
#            x30EB: x0E03  BRnzp DIVINIT (or 3)                      [line: 189]
# DIVNEG2:   x30EC: x96FF  NOT R3, R3                                [line: 190]
#            x30ED: x927F  NOT R1, R1                                [line: 191]
#            x30EE: x1261  ADD R1, R1, #1                            [line: 192]
# DIVINIT:   x30EF: x1860  ADD R4, R1, #0                            [line: 193]
#            x30F0: x993F  NOT R4, R4                                [line: 194]
#            x30F1: x1921  ADD R4, R4, #1                            [line: 195]
# DIVLOOP:   x30F2: x1404  ADD R2, R0, R4                            [line: 196]
#            x30F3: x0805  BRn DIVDONE (or 5)                        [line: 197]
#            x30F4: x1004  ADD R0, R0, R4                            [line: 198]
#            x30F5: x240C  LD R2, QUOTIENT                           [line: 199]
#            x30F6: x14A1  ADD R2, R2, #1                            [line: 200]
#            x30F7: x340A  ST R2, QUOTIENT                           [line: 201]
#            x30F8: x0FF9  BRnzp DIVLOOP                             [line: 202]
# DIVDONE:   x30F9: x16E0  ADD R3, R3, #0                            [line: 203]
#            x30FA: x0604  BRzp DIVRET (or 4)                        [line: 204]
#            x30FB: x2406  LD R2, QUOTIENT                           [line: 205]
#            x30FC: x94BF  NOT R2, R2                                [line: 206]
#            x30FD: x14A1  ADD R2, R2, #1                            [line: 207]
#            x30FE: x3403  ST R2, QUOTIENT                           [line: 208]
# DIVRET:    x30FF: x3003  ST R0, REMAINDER                          [line: 209]
#            x3100: xE178  LEA R0, POP                               [line: 210]
#            x3101: xC000  JMP R0                                    [line: 211]
# QUOTIENT:  x3102: x0000  NOOP - (no BR to REMAINDER) (or 0)        [line: 212]
# REMAINDER: x3103: x000A  NOOP - (no BR to x310E) (or 10)           [line: 213]
#            x3104: x0000  NOOP - (no BR to x3105) (or 0)            [line: 214]
